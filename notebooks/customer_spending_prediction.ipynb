# %% [markdown]
# # Customer Spending Prediction Using Machine Learning
#
# ML Workshop project: predict total customer spending and compare regression models using MAE, RMSE and R².

# %%
# Run the complete project from the repository root
# %run run_project.py

# %% [markdown]
# ## Models
#
# 1. Linear Regression using Income as a baseline
# 2. Multiple Linear Regression using demographic and behavior features
# 3. KNN Regressor
#
# The best model is selected using R² while also considering MAE and RMSE.

# %%
import pandas as pd
metrics = pd.read_csv('results/regression_metrics.csv')
metrics

# %% [markdown]
# ## Conclusion
#
# Multiple Linear Regression is expected to outperform the single-feature baseline because it uses several customer attributes simultaneously. The exact values are produced by `run_project.py` and saved under `results/`.
